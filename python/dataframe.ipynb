# %% [markdown]
# ## Import des données (et vérification de l'import)

# %%
import pandas as pd

# %%
df = pd.read_csv("clients.csv")

# %%
df.head()
# Out:
#    identifiant                      email               nom genre
# 0            0  LaurentDagenais@rhyta.com  Laurent Dagenais     M
# 1            1      GuyMarois@fleckens.hu        Guy Marois     M
# 2            2  BeaufortLesage@einrot.com   Beaufort Lesage     M
# 3            3  RussellDurand@armyspy.com    Russell Durand     M
# 4            4       AlexisRiel@rhyta.com       Alexis Riel     M

# %%
df.shape
# Out:
# (228, 4)

# %%
print("Ce dataframe contient", df.shape[0]," lignes et", df.shape[1],"colonnes.")
# Out:
# Ce dataframe contient 228  lignes et 5 colonnes.

# %%
df.dtypes
# Out:
# identifiant     int64
# email          object
# nom            object
# genre          object
# dtype: object

# %% [markdown]
# ## Commandes utiles

# %% [markdown]
# ### Récupérer une colonne et en faire un Data Series

# %%
data_mail = df["email"]
data_mail
# Out:
# 0            LaurentDagenais@rhyta.com
# 1                GuyMarois@fleckens.hu
# 2            BeaufortLesage@einrot.com
# 3            RussellDurand@armyspy.com
# 4                 AlexisRiel@rhyta.com
#                     ...
# 223    ClaudeDandonneau@jourrapide.com
# 224      ApollineMichaud@superrito.com
# 225         PascalineBeaudry@rhyta.com
# 226       FleurCaouette@jourrapide.com
# 227        FrancisMasse@jourrapide.com
# Name: email, Length: 228, dtype: object

# %% [markdown]
# ### Ajouter une colonne

# %%
df
# Out:
#      identifiant                            email                nom genre
# 0              0        LaurentDagenais@rhyta.com   Laurent Dagenais     M
# 1              1            GuyMarois@fleckens.hu         Guy Marois     M
# 2              2        BeaufortLesage@einrot.com    Beaufort Lesage     M
# 3              3        RussellDurand@armyspy.com     Russell Durand     M
# 4              4             AlexisRiel@rhyta.com        Alexis Riel     M
# ..           ...                              ...                ...   ...
# 223          223  ClaudeDandonneau@jourrapide.com  Claude Dandonneau     F
# 224          224    ApollineMichaud@superrito.com   Apolline Michaud     F
# 225          225       PascalineBeaudry@rhyta.com  Pascaline Beaudry     F
# 226          226     FleurCaouette@jourrapide.com     Fleur Caouette     F
# 227          227      FrancisMasse@jourrapide.com      Francis Masse     M
#
# [228 rows x 4 columns]

# %%
df["nouvelle colonne"] = df["identifiant"]*2

# %%
df
# Out:
#      identifiant                            email                nom genre  \
# 0              0        LaurentDagenais@rhyta.com   Laurent Dagenais     M
# 1              1            GuyMarois@fleckens.hu         Guy Marois     M
# 2              2        BeaufortLesage@einrot.com    Beaufort Lesage     M
# 3              3        RussellDurand@armyspy.com     Russell Durand     M
# 4              4             AlexisRiel@rhyta.com        Alexis Riel     M
# ..           ...                              ...                ...   ...
# 223          223  ClaudeDandonneau@jourrapide.com  Claude Dandonneau     F
# 224          224    ApollineMichaud@superrito.com   Apolline Michaud     F
# 225          225       PascalineBeaudry@rhyta.com  Pascaline Beaudry     F
# 226          226     FleurCaouette@jourrapide.com     Fleur Caouette     F
# 227          227      FrancisMasse@jourrapide.com      Francis Masse     M
#
#      nouvelle colonne
# 0                   0
# ...

# %% [markdown]
# ### Supprimer une colonne

# %% [markdown]
# Je crée deux nouvelles colonnes pour tester les 3 méthodes

# %%
df["new1"] = 0
df["new2"] = 0
df.head()
# Out:
#    identifiant                      email               nom genre  \
# 0            0  LaurentDagenais@rhyta.com  Laurent Dagenais     M
# 1            1      GuyMarois@fleckens.hu        Guy Marois     M
# 2            2  BeaufortLesage@einrot.com   Beaufort Lesage     M
# 3            3  RussellDurand@armyspy.com    Russell Durand     M
# 4            4       AlexisRiel@rhyta.com       Alexis Riel     M
#
#    nouvelle colonne  new1  new2
# 0                 0     0     0
# 1                 2     0     0
# 2                 4     0     0
# 3                 6     0     0
# 4                 8     0     0

# %% [markdown]
# #### 1<sup>re</sup> méthode

# %%
df.drop(columns="nouvelle colonne")
# Out:
#      identifiant                            email                nom genre  \
# 0              0        LaurentDagenais@rhyta.com   Laurent Dagenais     M
# 1              1            GuyMarois@fleckens.hu         Guy Marois     M
# 2              2        BeaufortLesage@einrot.com    Beaufort Lesage     M
# 3              3        RussellDurand@armyspy.com     Russell Durand     M
# 4              4             AlexisRiel@rhyta.com        Alexis Riel     M
# ..           ...                              ...                ...   ...
# 223          223  ClaudeDandonneau@jourrapide.com  Claude Dandonneau     F
# 224          224    ApollineMichaud@superrito.com   Apolline Michaud     F
# 225          225       PascalineBeaudry@rhyta.com  Pascaline Beaudry     F
# 226          226     FleurCaouette@jourrapide.com     Fleur Caouette     F
# 227          227      FrancisMasse@jourrapide.com      Francis Masse     M
#
#      new1  new2
# 0       0     0
# 1       0     0
# ...

# %% [markdown]
# 2<sup>e</sup> méthode

# %%
del df["new1"]

# %%
df.head()
# Out:
#    identifiant                      email               nom genre  \
# 0            0  LaurentDagenais@rhyta.com  Laurent Dagenais     M
# 1            1      GuyMarois@fleckens.hu        Guy Marois     M
# 2            2  BeaufortLesage@einrot.com   Beaufort Lesage     M
# 3            3  RussellDurand@armyspy.com    Russell Durand     M
# 4            4       AlexisRiel@rhyta.com       Alexis Riel     M
#
#    nouvelle colonne  new2
# 0                 0     0
# 1                 2     0
# 2                 4     0
# 3                 6     0
# 4                 8     0

# %% [markdown]
# 3<sup>e</sup> méthode

# %%
df.pop("new2")
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 223    0
# 224    0
# 225    0
# 226    0
# 227    0
# Name: new2, Length: 228, dtype: int64

# %%
df.head()
# Out:
#    identifiant                      email               nom genre  \
# 0            0  LaurentDagenais@rhyta.com  Laurent Dagenais     M
# 1            1      GuyMarois@fleckens.hu        Guy Marois     M
# 2            2  BeaufortLesage@einrot.com   Beaufort Lesage     M
# 3            3  RussellDurand@armyspy.com    Russell Durand     M
# 4            4       AlexisRiel@rhyta.com       Alexis Riel     M
#
#    nouvelle colonne
# 0                 0
# 1                 2
# 2                 4
# 3                 6
# 4                 8
